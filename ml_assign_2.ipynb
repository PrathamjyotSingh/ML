# %%
import pandas as pd

# %%
df=pd.DataFrame()
df['name']=['qwe','rty','uiop','asd','fghj','zxc','vbn','plm','uite','dfh']
df['age']=[68,85,85,34,56,98,42,35,53,31]
df['gender']=['male','female','male','female','male','female','male','female','male','female']
df['address']=['wert','sdfg','utyy','uiop','fghj','hfsutk','dgjcmf','gjcnbcd','cbmv','jgcfjhf']
df
# Out:
#    name  age  gender  address
# 0   qwe   68    male     wert
# 1   rty   85  female     sdfg
# 2  uiop   85    male     utyy
# 3   asd   34  female     uiop
# 4  fghj   56    male     fghj
# 5   zxc   98  female   hfsutk
# 6   vbn   42    male   dgjcmf
# 7   plm   35  female  gjcnbcd
# 8  uite   53    male     cbmv
# 9   dfh   31  female  jgcfjhf

# %%
df.iloc[3]
df.iloc[1:3]
df.iloc[1:3,0:2]
# Out:
#    name  age
# 1   rty   85
# 2  uiop   85

# %%
df[df['age']>60]
# Out:
#    name  age  gender address
# 0   qwe   68    male    wert
# 1   rty   85  female    sdfg
# 2  uiop   85    male    utyy
# 5   zxc   98  female  hfsutk

# %%
df.replace(['male','female'],['woman','man'])
# Out:
#    name  age gender  address
# 0   qwe   68  woman     wert
# 1   rty   85    man     sdfg
# 2  uiop   85  woman     utyy
# 3   asd   34    man     uiop
# 4  fghj   56  woman     fghj
# 5   zxc   98    man   hfsutk
# 6   vbn   42  woman   dgjcmf
# 7   plm   35    man  gjcnbcd
# 8  uite   53  woman     cbmv
# 9   dfh   31    man  jgcfjhf

# %%
df.rename(columns={'name':'adhaar'})
# Out:
#   adhaar  age  gender  address
# 0    qwe   68    male     wert
# 1    rty   85  female     sdfg
# 2   uiop   85    male     utyy
# 3    asd   34  female     uiop
# 4   fghj   56    male     fghj
# 5    zxc   98  female   hfsutk
# 6    vbn   42    male   dgjcmf
# 7    plm   35  female  gjcnbcd
# 8   uite   53    male     cbmv
# 9    dfh   31  female  jgcfjhf

# %%
print(df['age'].max())
print(df['age'].min())
print(df['age'].sum())
print(df['age'].mean())
print(df['age'].count())
# Out:
# 98
# 31
# 587
# 58.7
# 10

# %%
print(df['gender'].unique())
print(df['gender'].nunique())
print(df['gender'].value_counts())
# Out:
# ['male' 'female']
# 2
# gender
# male      5
# female    5
# Name: count, dtype: int64

# %%
df.drop(['age'],axis=1)
# Out:
#    name  gender  address
# 0   qwe    male     wert
# 1   rty  female     sdfg
# 2  uiop    male     utyy
# 3   asd  female     uiop
# 4  fghj    male     fghj
# 5   zxc  female   hfsutk
# 6   vbn    male   dgjcmf
# 7   plm  female  gjcnbcd
# 8  uite    male     cbmv
# 9   dfh  female  jgcfjhf

# %%
df.drop_duplicates()
# Out:
#    name  age  gender  address
# 0   qwe   68    male     wert
# 1   rty   85  female     sdfg
# 2  uiop   85    male     utyy
# 3   asd   34  female     uiop
# 4  fghj   56    male     fghj
# 5   zxc   98  female   hfsutk
# 6   vbn   42    male   dgjcmf
# 7   plm   35  female  gjcnbcd
# 8  uite   53    male     cbmv
# 9   dfh   31  female  jgcfjhf

# %%
print(df.groupby('gender').max())
# Out:
#        name  age address
# gender
# female  zxc   98    uiop
# male    vbn   85    wert

# %%
for name in df['name']:
    print(name.upper())
# Out:
# QWE
# RTY
# UIOP
# ASD
# FGHJ
# ZXC
# VBN
# PLM
# UITE
# DFH

# %%
import numpy as np
df['age'].apply(np.sqrt)
# Out:
# 0    8.246211
# 1    9.219544
# 2    9.219544
# 3    5.830952
# 4    7.483315
# 5    9.899495
# 6    6.480741
# 7    5.916080
# 8    7.280110
# 9    5.567764
# Name: age, dtype: float64

# %%
print(pd.isna(df))
# Out:
#     name    age  gender  address
# 0  False  False   False    False
# 1  False  False   False    False
# 2  False  False   False    False
# 3  False  False   False    False
# 4  False  False   False    False
# 5  False  False   False    False
# 6  False  False   False    False
# 7  False  False   False    False
# 8  False  False   False    False
# 9  False  False   False    False

# %%
df.loc[df['age'] > 60, 'age'] = np.nan
df
# Out:
#    name   age  gender  address
# 0   qwe   NaN    male     wert
# 1   rty   NaN  female     sdfg
# 2  uiop   NaN    male     utyy
# 3   asd  34.0  female     uiop
# 4  fghj  56.0    male     fghj
# 5   zxc   NaN  female   hfsutk
# 6   vbn  42.0    male   dgjcmf
# 7   plm  35.0  female  gjcnbcd
# 8  uite  53.0    male     cbmv
# 9   dfh  31.0  female  jgcfjhf

# %%
df['age'].fillna(69,inplace=True)
df
# Out:
#    name   age  gender  address
# 0   qwe  69.0    male     wert
# 1   rty  69.0  female     sdfg
# 2  uiop  69.0    male     utyy
# 3   asd  34.0  female     uiop
# 4  fghj  56.0    male     fghj
# 5   zxc  69.0  female   hfsutk
# 6   vbn  42.0    male   dgjcmf
# 7   plm  35.0  female  gjcnbcd
# 8  uite  53.0    male     cbmv
# 9   dfh  31.0  female  jgcfjhf

# %%
df.loc[df['age'] < 40, 'age'] = np.nan
# print(df)
df.dropna(inplace=True)
df
# Out:
#    name   age  gender address
# 0   qwe  69.0    male    wert
# 1   rty  69.0  female    sdfg
# 2  uiop  69.0    male    utyy
# 4  fghj  56.0    male    fghj
# 5   zxc  69.0  female  hfsutk
# 6   vbn  42.0    male  dgjcmf
# 8  uite  53.0    male    cbmv

# %%
df.loc[df['age'] == 69, 'age'] = np.nan
df.fillna(method='pad')
df.fillna(method='bfill')
df
# Out:
#    name   age  gender address
# 0   qwe   NaN    male    wert
# 1   rty   NaN  female    sdfg
# 2  uiop   NaN    male    utyy
# 4  fghj  56.0    male    fghj
# 5   zxc   NaN  female  hfsutk
# 6   vbn  42.0    male  dgjcmf
# 8  uite  53.0    male    cbmv

# %%
from sklearn.impute import SimpleImputer
mean_imputer=SimpleImputer(missing_values=np.nan,strategy="mean")
mean_imputer.fit_transform((df['age'].values).reshape(1,-1))
df
# Out:
# /usr/local/lib/python3.10/dist-packages/sklearn/impute/_base.py:558: UserWarning: Skipping features without any observed values: [0 1 2 4]. At least one non-missing value is needed for imputation with strategy='mean'.
#   warnings.warn(
#    name   age  gender address
# 0   qwe   NaN    male    wert
# 1   rty   NaN  female    sdfg
# 2  uiop   NaN    male    utyy
# 4  fghj  56.0    male    fghj
# 5   zxc   NaN  female  hfsutk
# 6   vbn  42.0    male  dgjcmf
# 8  uite  53.0    male    cbmv

# %%
from sklearn.impute import KNNImputer
X_filled_knn=KNNImputer(n_neighbors=1).fit_transform((df['age'].values).reshape(1,-1))
X_filled_knn
# Out:
# array([[56., 42., 53.]])
